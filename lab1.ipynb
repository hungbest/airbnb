# %% [markdown]
# <a href="https://colab.research.google.com/github/hungbest/airbnb/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sympy

# %%
##EXERCISE 1
## a
import math
def exponentiallFunction_a(x):
  return math.sqrt(x)
## b
def exponentiallFunction_b(x):
  return pow(x, 1/3)

## c
def exponentiallFunction_c(x):
  return math.pow(x, 2/3)

## d
def expresstionFunction_d(x):
  return math.pow(x, 3)/3 + math.pow(x, 2)/2 - 2*x + 1/3

## e
def fractionFunction_e(x):
  return (2*math.pow(x, 2) - 3)/(7*x + 4)

## f
def fractionFunction_f(x):
  return (5*math.pow(x, 2) + 8*x -3)/(3*math.pow(x, 2) + 2)

## g
def trigonometricFunction_g(x):
  return math.sin(x)

## h
def trigonometricFunction_h(x):
  return math.cos(x)

## i
def logarithmicallyFunction_i(x):
  return math.pow(3, x)

## j
def logarithmicallyFunction_j(x):
  return math.pow(10, -x)

## k
def logarithmicallyFunction_k(x):
  return math.exp(x)

## l
def logarithmicFunction_l(x):
  return math.log2(x)

## m
def logarithmicFunction_m(x):
  return math.log10(x)

## n
def logarithmicFunction_n(x):
  return math.log(x)

## EXERCISE 2
## a
def functionA():
  arrA = [-2, -1, 0, 1, 2]
  for item in arrA:
    result = 2 + (math.pow(item, 2))/(math.pow(item, 2) + 4)
    print('f({}) = {}'.format(item, result))

## b
def functionB():
  arrB = [0, 1, 2, 3, 4, 5]
  for item in arrB:
    result = math.sqrt(5*item + 10)
    print('f({}) = {}'.format(item, result))

## c
def functionC():
  arrC = [5, 6, 7, 8, 9, 10]
  for item in arrC:
    result = 2/(math.pow(x, 2) - 16)
    print('f({}) = {}'.format(item, result))

## d
def functionD():
  arrD = [5, 6, 7, 8, 9, 10]
  for item in arrD:
    result = math.pow(x, 4) + 3*math.pow(x, 2) - 1
    print('f({}) = {}'.format(item, result))

## e
def functionE(x):
  if(x >= 0):
    return x
  else:
    return -x

## f
def functionF(x):
  if(x < 0):
    return -x
  elif (x >= 0 and x <= 1):
    return math.pow(x, 2)
  else:
    return 1

x = 10
print('=========================EXERCISE 1===========================')
print('exponentiallFunction_a: f(x) = ', exponentiallFunction_a(x))
print('exponentiallFunction_b: f(x) = ', exponentiallFunction_b(x))
print('exponentiallFunction_c: f(x) = ', exponentiallFunction_c(x))
print('expresstionFunction_d: f(x) = ', expresstionFunction_d(x))
print('fractionFunction_e: f(x) = ', fractionFunction_e(x))
print('fractionFunction_f: f(x) = ', fractionFunction_f(x))
print('trigonometricFunction_g: f(x) = ', trigonometricFunction_g(x))
print('trigonometricFunction_h: f(x) = ', trigonometricFunction_h(x))
print('logarithmicallyFunction_i: f(x) = ', logarithmicallyFunction_i(x))
print('logarithmicallyFunction_j: f(x) = ', logarithmicallyFunction_j(x))
print('logarithmicallyFunction_k: f(x) = ', logarithmicallyFunction_k(x))
print('logarithmicFunction_l: f(x) = ', logarithmicFunction_l(x))
print('logarithmicFunction_m: f(x) = ', logarithmicFunction_m(x))
print('logarithmicFunction_n: f(x) = ', logarithmicFunction_n(x))

print('======================EXERCISE 2=========================')
print('FunctionA')
functionA()
print('FunctionB')
functionB()
print('FunctionC')
functionC()
print('FunctionD')
functionD()

print('FunctionE')
x = 3
print('f({}) = {}'.format(x, functionE(x)))
x = -3
print('f({}) = {}'.format(x, functionE(x)))

print('FunctionF')
x = 3
print('f({}) = {}'.format(x, functionF(x)))
x = -3
print('f({}) = {}'.format(x, functionF(x)))
x = 1/2
print('f({}) = {}'.format(x, functionF(x)))
# Out:
# =========================EXERCISE 1===========================
# exponentiallFunction_a: f(x) =  3.1622776601683795
# exponentiallFunction_b: f(x) =  2.154434690031884
# exponentiallFunction_c: f(x) =  4.641588833612778
# expresstionFunction_d: f(x) =  363.66666666666663
# fractionFunction_e: f(x) =  2.6621621621621623
# fractionFunction_f: f(x) =  1.9105960264900663
# trigonometricFunction_g: f(x) =  -0.5440211108893698
# trigonometricFunction_h: f(x) =  -0.8390715290764524
# logarithmicallyFunction_i: f(x) =  59049.0
# logarithmicallyFunction_j: f(x) =  1e-10
# logarithmicallyFunction_k: f(x) =  22026.465794806718
# logarithmicFunction_l: f(x) =  3.321928094887362
# logarithmicFunction_m: f(x) =  1.0
# logarithmicFunction_n: f(x) =  2.302585092994046
# ======================EXERCISE 2=========================
# FunctionA
# f(-2) = 2.5
# f(-1) = 2.2
# f(0) = 2.0
# f(1) = 2.2
# f(2) = 2.5
# FunctionB
# f(0) = 3.1622776601683795
# f(1) = 3.872983346207417
# f(2) = 4.47213595499958
# ...
